# %%
# Install requierements
# !pip install requests
# !pip install pandas

# %%
# Import requerements
import requests
import pandas as pd

# %%
# Create header and API url

header = {
"access-control-allow-origin" : "*",
"content-encoding" : "gzip,",
"content-type" : "text/plain",
"date" : "Thu, 26 May 2022 07:27:58 GMT",
#"etag": W/"628ebfe0-27b7b",
"last-modified" : "Wed, 25 May 2022 23:46:40 GMT",
"server" : "nginx"
}

url = "https://forecast.waqi.info/forecast/aqi/silam/glob/best/pm25/jsmap/049.jsmap"
res = requests.get(url, headers=header)

res.status_code
df_raw = res.text
df_raw
# Out:
# '{"size":[1800,897],"bounds":[[-89.5999984741211,-179.8000030517578],[89.5999984741211,180.00001525878906]],"standard":{"range":[4,2,2,2,2,2,2],"domain":[0,12,35,65,150,250,350,500],"lut":[2.9,5.9,8.9,11.9,23.4,34.9,49.9,64.9,107.4,149.9,199.9,249.9,299.9,349.9,424.9,499.9,500]},"variable":{"id":"pm25","unit":"ug/m3","name":"PM25"},"datetime":"2022-05-24T01:00:00Z","data":"...","stride":1800}'
